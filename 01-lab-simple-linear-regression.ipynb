# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('/kaggle/input/datasets/kaustubhbanga/placement/placement.csv')
df=df[:10]
df
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
# 5  7.89     2.99
# 6  6.73     2.60
# 7  6.75     2.48
# 8  6.09     2.31
# 9  8.31     3.51

# %%
sns.scatterplot(data=df,
               x=df['cgpa'],
               y=df['package']);

# %%
model=LinearRegression()
model.fit(df[['cgpa']], df['package'])
# Out:
# LinearRegression()

# %%
m = model.coef_
m
# Out:
# array([0.49105006])

# %%
c=model.intercept_
c
# Out:
# np.float64(-0.4733861893363027)

# %%
x=df['cgpa']
y=df['package']
y_pred = model.predict(df[['cgpa']])

# %%
sns.scatterplot(data = df, x = df['cgpa'], y = df['package'])
plt.plot(df['cgpa'], y_pred, color = 'pink');

# %%
y
# Out:
# 0    3.26
# 1    1.98
# 2    3.25
# 3    3.67
# 4    3.57
# 5    2.99
# 6    2.60
# 7    2.48
# 8    2.31
# 9    3.51
# Name: package, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
#calculate mae
mae = np.sum(np.abs((y-y_pred)))/len(y)
mae
# Out:
# np.float64(0.29706897708387314)

# %%
#calculate mae with formula
mae = mean_absolute_error(y,y_pred)
mae
# Out:
# 0.29706897708387314

# %%
#calculate mse manually 
mse = np.sum((y-y_pred)**2)/len(y)
mse
# Out:
# np.float64(0.11987595659200753)

# %%
#calculate mse with formula
mse = mean_squared_error(y,y_pred)
mse
# Out:
# 0.11987595659200753

# %%
#calculate rmse manually
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(0.3462310739838461)

# %%
#calculate rmse with formula
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(0.3462310739838461)

# %%
#calculate r2 score manually
ymean = np.mean(y)
ymean
sse_reg = np.sum((y - y_pred)**2)
# print(sse_reg)
sse_mean = np.sum((y - ymean)**2)
# print(sse_mean)
# r2_manual = (sse_mean - sse_reg)/sse_mean
#or
r2_manual = 1 - (sse_reg / sse_mean)
r2_manual
# Out:
# np.float64(0.6128737806081344)

# %%
#calculate r2 score with formula 
r2= r2_score(y, y_pred)
r2
# Out:
# 0.6128737806081344
